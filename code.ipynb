# %%
import pandas as pd
df = pd.read_csv("Steel_industry_data.csv")
df
# Out:
#                    date  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# 0      01/01/2018 00:15       3.17                                  2.95
# 1      01/01/2018 00:30       4.00                                  4.46
# 2      01/01/2018 00:45       3.24                                  3.28
# 3      01/01/2018 01:00       3.31                                  3.56
# 4      01/01/2018 01:15       3.82                                  4.50
# ...                 ...        ...                                   ...
# 35035  31/12/2018 23:00       3.85                                  4.86
# 35036  31/12/2018 23:15       3.74                                  3.74
# 35037  31/12/2018 23:30       3.78                                  3.17
# 35038  31/12/2018 23:45       3.78                                  3.06
# 35039  31/12/2018 00:00       3.67                                  3.02
#
#        Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
# ...

# %%
df.shape
# Out:
# (35040, 11)

# %%
import pandas as pd




df[['Leading_Current_Reactive_Power_kVarh']] = df[['Leading_Current_Reactive_Power_kVarh']].replace(0, pd.NA)


print(df[['Leading_Current_Reactive_Power_kVarh']].isna().sum())
# Out:
# Leading_Current_Reactive_Power_kVarh    23610
# dtype: int64

# %%
df['Leading_Current_Reactive_Power_kVarh'].fillna(df['Leading_Current_Reactive_Power_kVarh'].mean(), inplace=True)
# Out:
# C:\Users\VIHASHINI\AppData\Local\Temp\ipykernel_22068\3128488792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Leading_Current_Reactive_Power_kVarh'].fillna(df['Leading_Current_Reactive_Power_kVarh'].mean(), inplace=True)
# ...

# %%
df.isna().sum()
# Out:
# date                                    0
# Usage_kWh                               0
# Lagging_Current_Reactive.Power_kVarh    0
# Leading_Current_Reactive_Power_kVarh    0
# CO2(tCO2)                               0
# Lagging_Current_Power_Factor            0
# Leading_Current_Power_Factor            0
# NSM                                     0
# WeekStatus                              0
# Day_of_week                             0
# Load_Type                               0
# dtype: int64

# %%
df.dtypes
# Out:
# date                                     object
# Usage_kWh                               float64
# Lagging_Current_Reactive.Power_kVarh    float64
# Leading_Current_Reactive_Power_kVarh    float64
# CO2(tCO2)                               float64
# Lagging_Current_Power_Factor            float64
# Leading_Current_Power_Factor            float64
# NSM                                       int64
# WeekStatus                               object
# Day_of_week                              object
# Load_Type                                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date                                  35040 non-null  object
#  1   Usage_kWh                             35040 non-null  float64
#  2   Lagging_Current_Reactive.Power_kVarh  35040 non-null  float64
#  3   Leading_Current_Reactive_Power_kVarh  35040 non-null  float64
#  4   CO2(tCO2)                             35040 non-null  float64
#  5   Lagging_Current_Power_Factor          35040 non-null  float64
#  6   Leading_Current_Power_Factor          35040 non-null  float64
#  7   NSM                                   35040 non-null  int64
#  8   WeekStatus                            35040 non-null  object
#  9   Day_of_week                           35040 non-null  object
# ...

# %%
df.describe()
# Out:
#           Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
# count  35040.000000                          35040.000000
# mean      27.386892                             13.035384
# std       33.444380                             16.306000
# min        0.000000                              0.000000
# 25%        3.200000                              2.300000
# 50%        4.570000                              5.000000
# 75%       51.237500                             22.640000
# max      157.180000                             96.910000
#
#        Leading_Current_Reactive_Power_kVarh     CO2(tCO2)  \
# count                          35040.000000  35040.000000
# mean                              11.866845      0.011524
# std                                4.916305      0.016151
# min                                0.040000      0.000000
# 25%                               11.866845      0.000000
# 50%                               11.866845      0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in ['WeekStatus','Day_of_week','Load_Type']:
    print(f"{col}:{df[col].nunique()}")
    print(f"{col}:{df[col].unique()}")
# Out:
# WeekStatus:2
# WeekStatus:['Weekday' 'Weekend']
# Day_of_week:7
# Day_of_week:['Monday' 'Tuesday' 'Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday']
# Load_Type:3
# Load_Type:['Light_Load' 'Medium_Load' 'Maximum_Load']

# %%
import numpy as np


num_cols = df.select_dtypes(include=['float64','int64']).columns


skew_vals = df[num_cols].skew().sort_values(ascending=False)
print("Skewness of numeric columns:\n", skew_vals)
# Out:
# Skewness of numeric columns:
#  Lagging_Current_Reactive.Power_kVarh    1.437899
# Usage_kWh                               1.197394
# CO2(tCO2)                               1.149355
# Leading_Current_Reactive_Power_kVarh    0.019156
# NSM                                     0.000000
# Lagging_Current_Power_Factor           -0.606126
# Leading_Current_Power_Factor           -1.511984
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cat_cols = ['WeekStatus', 'Day_of_week', 'Load_Type']

for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[col])
    plt.title(f"Count of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
from imblearn.over_sampling import RandomOverSampler

X = df.drop('WeekStatus',axis=1)
y = df['WeekStatus']

ros = RandomOverSampler(random_state=42)
X_res, y_res = ros.fit_resample(X, y)

# %%
import pandas as pd
balanced_df = pd.concat([X_res, y_res], axis=1)
sns.countplot(x='WeekStatus',data=balanced_df)
plt.title("After Balancing")
plt.show()

# %%
sns.countplot(x='Load_Type',data=balanced_df)
plt.title("After Balancing")
plt.show()

# %%
from imblearn.over_sampling import RandomOverSampler

X = df.drop('Load_Type', axis=1)
y = df['Load_Type']

ros = RandomOverSampler(random_state=42)
X_res, y_res = ros.fit_resample(X, y)

balanced_df = pd.concat([X_res, y_res], axis=1)

# %%
num_df = df.select_dtypes(include=['float64', 'int64'])

corr = num_df.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features", fontsize=14)
plt.show()

# %%
cols_to_remove = ['CO2(tCO2)', 'Lagging_Current_Reactive.Power_kVarh']

cols_to_remove = [col for col in cols_to_remove if col in df.columns]

df = df.drop(columns=cols_to_remove)

print(df.head())
# Out:
#                date  Usage_kWh  Leading_Current_Reactive_Power_kVarh  \
# 0  01/01/2018 00:15       3.17                             11.866845
# 1  01/01/2018 00:30       4.00                             11.866845
# 2  01/01/2018 00:45       3.24                             11.866845
# 3  01/01/2018 01:00       3.31                             11.866845
# 4  01/01/2018 01:15       3.82                             11.866845
#
#    Lagging_Current_Power_Factor  Leading_Current_Power_Factor   NSM  \
# 0                         73.21                         100.0   900
# 1                         66.77                         100.0  1800
# 2                         70.28                         100.0  2700
# 3                         68.09                         100.0  3600
# 4                         64.72                         100.0  4500
#
#   WeekStatus Day_of_week   Load_Type
# 0    Weekday      Monday  Light_Load
# 1    Weekday      Monday  Light_Load
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


num_cols = df.select_dtypes(include=np.number).columns

for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer


skewness = df[num_cols].skew()
skewed_cols = skewness[abs(skewness) > 0.5].index
print("Columns to transform:", list(skewed_cols))

from sklearn.preprocessing import QuantileTransformer

df_quantile = df.copy()

qt = QuantileTransformer(output_distribution='normal', random_state=42)
df_quantile[skewed_cols] = qt.fit_transform(df[skewed_cols])

print("Skewness after Quantile Transform:\n", df_quantile[skewed_cols].skew())
# Out:
# Columns to transform: ['Usage_kWh', 'Lagging_Current_Reactive.Power_kVarh', 'CO2(tCO2)', 'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor']
# Skewness after Quantile Transform:
#  Usage_kWh                              -0.013940
# Lagging_Current_Reactive.Power_kVarh   -1.142925
# CO2(tCO2)                               0.449701
# Lagging_Current_Power_Factor            1.100107
# Leading_Current_Power_Factor           -0.891592
# dtype: float64

# %%
for col in skewed_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df_quantile[col], kde=True, bins=30)
    plt.title(f"Distribution After Transformation: {col}")
    plt.show()

# %%
X = df.drop(columns=['Usage_kWh', 'date']) 
y = df['Usage_kWh']

# %%
categorical_cols = ['WeekStatus', 'Day_of_week', 'Load_Type']
numerical_cols = [col for col in X.columns if col not in categorical_cols]
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_encoded[numerical_cols] = scaler.fit_transform(X_encoded[numerical_cols])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)
print(X_train.shape)
# Out:
# (28032, 13)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR
regressors = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet": ElasticNet(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42, n_estimators=100),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42, n_estimators=100),
    "AdaBoost": AdaBoostRegressor(random_state=42, n_estimators=100),
    "Support Vector Regressor": SVR()
}

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
results = []

for name, model in regressors.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    results.append({
        "Model": name,
        "MSE": mse,
        "RMSE": rmse,
        "MAE": mae,
        "R2 Score": r2
    })

results_df = pd.DataFrame(results)
print(results_df.sort_values(by="R2 Score", ascending=False))
# Out:
#                       Model         MSE       RMSE        MAE  R2 Score
# 6         Gradient Boosting  188.337946  13.723627   7.629795  0.834315
# 5             Random Forest  191.806445  13.849420   6.637452  0.831264
# 7                  AdaBoost  275.045181  16.584486  11.010044  0.758037
# 8  Support Vector Regressor  293.063975  17.119111   8.816207  0.742185
# 4             Decision Tree  337.385320  18.368052   8.427589  0.703195
# 0         Linear Regression  390.060829  19.749958  14.807556  0.656855
# 1          Ridge Regression  390.062782  19.750007  14.807169  0.656853
# 2          Lasso Regression  412.203077  20.302785  14.560881  0.637376
# 3                ElasticNet  611.427958  24.727069  18.785246  0.462113

# %%
print(X_train.columns.tolist())
# Out:
# ['Leading_Current_Reactive_Power_kVarh', 'Lagging_Current_Power_Factor', 'Leading_Current_Power_Factor', 'NSM', 'WeekStatus_Weekend', 'Day_of_week_Monday', 'Day_of_week_Saturday', 'Day_of_week_Sunday', 'Day_of_week_Thursday', 'Day_of_week_Tuesday', 'Day_of_week_Wednesday', 'Load_Type_Maximum_Load', 'Load_Type_Medium_Load']

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

rf = RandomForestRegressor(random_state=42)
gb = GradientBoostingRegressor(random_state=42)

rf_params = {
    'n_estimators': [100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

gb_params = {
    'n_estimators': [100, 200],
    'learning_rate': [0.05, 0.1],
    'max_depth': [3, 5],
    'min_samples_split': [2, 5]
}


rf_random = RandomizedSearchCV(rf, rf_params, n_iter=5, cv=3,random_state=42)
gb_random = RandomizedSearchCV(gb, gb_params, n_iter=5, cv=3,random_state=42)


rf_random.fit(X_train, y_train)
gb_random.fit(X_train, y_train)


best_rf = rf_random.best_estimator_
best_gb = gb_random.best_estimator_

print("Best RF Params:", rf_random.best_params_)
print("Best GB Params:", gb_random.best_params_)

for name, model in zip(['Random Forest', 'Gradient Boosting'], [best_rf, best_gb]):
    y_pred = model.predict(X_test)
    print(f"\n{name} Performance:")
    print("MSE:", mean_squared_error(y_test, y_pred))
    print("RMSE:",np.sqrt(mse))
    print("MAE:", mean_absolute_error(y_test, y_pred))
    print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# Best RF Params: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 10}
# Best GB Params: {'n_estimators': 100, 'min_samples_split': 5, 'max_depth': 5, 'learning_rate': 0.1}
#
# Random Forest Performance:
# MSE: 173.00072230347757
# RMSE: 17.119111401770475
# MAE: 6.689351312556631
# R2 Score: 0.8478074050712259
#
# Gradient Boosting Performance:
# MSE: 171.38470431436699
# RMSE: 17.119111401770475
# MAE: 6.885556541512786
# R2 Score: 0.8492290521484148

# %%
import mlflow
import mlflow.sklearn

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score


model = GradientBoostingRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    min_samples_split=5
)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)


with mlflow.start_run() as run:
  
    mlflow.log_param("model_name", "GradientBoosting")
    mlflow.log_param("n_estimators", 100)
    mlflow.log_param("learning_rate", 0.1)
    mlflow.log_param("max_depth", 5)
    mlflow.log_param("min_samples_split", 5)

    mlflow.log_metric("mae",mean_absolute_error(y_test, y_pred))
    mlflow.log_metric("mse",mean_squared_error(y_test, y_pred))
    mlflow.log_metric("rmse",np.sqrt(mse))
    mlflow.log_metric("r2", r2_score(y_test, y_pred))

   
    input_example = pd.DataFrame([X_train.iloc[0]])
    mlflow.sklearn.log_model(model, name="model", input_example=input_example)

    
    print("Run ID:", run.info.run_id)
# Out:
# ...
# Run ID: 7114947f93dc4b239b2da21c08c14b67
